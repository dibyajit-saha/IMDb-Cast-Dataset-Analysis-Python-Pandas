# %%
import pandas as pd

# %%
cast = pd.read_csv("C:/Users/DIBYAJIT/OneDrive/Desktop/Top Mentor/Advanced Modules and MySQL/Assignment/File/cast/cast.csv")
cast.head(10)
# Out:
#                                                title    year  \
# 0                                     Closet Monster  2015.0
# 1                                    Suuri illusioni  1985.0
# 2                                Battle of the Sexes  2017.0
# 3                               Secret in Their Eyes  2015.0
# 4                                         Steve Jobs  2015.0
# 5                             Straight Outta Compton  2015.0
# 6                             Straight Outta Compton  2015.0
# 7                                     For Thy Love 2  2009.0
# 8  Lapis, Ballpen at Diploma, a True to Life Journey  2014.0
# 9                                       Desire (III)  2014.0
#
#                         name   type                               character  \
# 0                   Buffy #1  actor                                 Buffy 4
# 1                     Homo $  actor                                  Guests
# ...

# %% [markdown]
# ### How many movies are listed in the titles dataframe?

# %%
print (cast['title'].nunique())
# Out:
# 166670

# %% [raw]
# print (cast['title'].unique())

# %% [markdown]
# ### What are the earliest two films listed in the titles dataframe?

# %%
earliest_film = cast.sort_values('year', ascending = True )
earliest_film.iloc [0:2]
# Out:
#              title    year               name   type  \
# 555929  Miss Jerry  1894.0     Chauncey Depew  actor
# 464860  Miss Jerry  1894.0  William Courtenay  actor
#
#                                                 character   n
# 555929  Himself - the Director of the New York Central... NaN
# 464860                                       Mr. Hamilton NaN

# %% [markdown]
# ### How many movies have the title "Hamlet"?

# %%
cast[cast ['title'] == 'Hamlet'].count
# Out:
# <bound method DataFrame.count of           title    year              name   type              character     n
# 1615     Hamlet  1996.0        Riz Abbasi  actor  Attendant to Claudius   1.0
# 7438     Hamlet  1921.0  Fritz Achterberg  actor            Fortinbras,   9.0
# 11242    Hamlet  2009.0      Hayden Adams  actor                Laertes   7.0
# 11243    Hamlet  2009.0      Hayden Adams  actor                 Player   7.0
# 13907    Hamlet  1913.0       Eric Adeney  actor               Reynaldo  14.0
# ...         ...     ...               ...    ...                    ...   ...
# 2113683  Hamlet  2015.0         Ben Stott  actor           Player Queen  12.0
# 2133184  Hamlet  2011.0   Haig Sutherland  actor                Laertes   NaN
# 2139408  Hamlet  1948.0      Basil Sydney  actor    Claudius - The King  11.0
# 2141264  Hamlet  1996.0   Thomas Szekeres  actor           Young Hamlet  41.0
# 2157738  Hamlet  1948.0       Tony Tarver  actor           Player Queen   7.0
#
# ...

# %%
## 218 movies have the title as "Hamlet"

# %% [markdown]
# ### How many movies are titled "North by Northwest"?

# %%
cast[cast['title'] == 'North by Northwest'].shape
# Out:
# (81, 6)

# %%
## 81 movies are titles 'North by Northwest'

# %% [markdown]
# ### When was the first movie titled "Hamlet" made?

# %%
a = earliest_film[earliest_film ['title'] == 'Hamlet']
a.iloc[0:1, [0,1]]
# Out:
#           title    year
# 1545289  Hamlet  1910.0

# %% [markdown]
# ### List all of the "Treasure Island" movies from earliest to most recent.

# %%
earliest_film[earliest_film['title'] == 'Treasure Island']
# Out:
#                    title    year               name   type  \
# 339256   Treasure Island  1918.0  Francis Carpenter  actor
# 830114   Treasure Island  1918.0     Charles Gorman  actor
# 1261579  Treasure Island  1918.0        Raymond Lee  actor
# 1715014  Treasure Island  1918.0         Lloyd Perl  actor
# 840745   Treasure Island  1918.0          Joe Grant  actor
# ...                  ...     ...                ...    ...
# 589900   Treasure Island  1999.0      Jamie Donovan  actor
# 1959741  Treasure Island  1999.0     Richard Schave  actor
# 1375015  Treasure Island  1999.0        J.P. Manoux  actor
# 934507   Treasure Island  1999.0          Pat Healy  actor
# 1637661  Treasure Island  1999.0      Nick Offerman  actor
#
#                        character     n
# 339256               Jim Hawkins   1.0
# 830114           Prologue Player   NaN
# 1261579                 Bit Role   NaN
# 1715014                Black Dog   4.0
# 840745   Undetermined child role   NaN
# ...

# %% [markdown]
# ### How many movies were made in the year 1950?

# %%
cast [cast['year'] == 1950].shape
# Out:
# (14653, 6)

# %% [markdown]
# ### How many movies were made in the year 1960?

# %%
cast [cast ['year'] == 1960].shape
# Out:
# (11551, 6)

# %% [markdown]
# ### How many movies were made from 1950 through 1959?

# %%
cast [cast ['year'].between (1950,1959)].shape
# Out:
# (137408, 6)

# %% [markdown]
# ### In what years has a movie titled "Batman" been released?

# %%
cast[cast['title'] == 'Batman'].iloc [:,[0,1]]
# Out:
#           title    year
# 95672    Batman  1943.0
# 96186    Batman  1943.0
# 114034   Batman  1989.0
# 119476   Batman  1989.0
# 149767   Batman  1989.0
# ...         ...     ...
# 2068050  Batman  1989.0
# 2096318  Batman  1989.0
# 2099960  Batman  1989.0
# 2115809  Batman  1989.0
# 2152546  Batman  1989.0
#
# [89 rows x 2 columns]

# %% [markdown]
# ### How many roles were there in the movie "Inception"?

# %%
cast [cast ['title'] == 'Inception']['character'].nunique()
# Out:
# 42

# %% [markdown]
# ### How many roles in the movie "Inception" are NOT ranked by an "n" value?

# %%
i = cast[cast['title']=='Inception']
i_no_n = i['n'].isnull().sum()
print (i_no_n)
# Out:
# 21

# %% [markdown]
# ### But how many roles in the movie "Inception" did receive an "n" value?

# %%
print (i['n'].count()) # i  is the previous variable
# Out:
# 31

# %% [markdown]
# ### Display the cast of "North by Northwest" in their correct "n"-value order, ignoring roles that did not earn a numeric "n" value.

# %%
n_sorted = cast.sort_values ('n', ascending = True).dropna()
n1 = n_sorted [n_sorted ['title'] == 'North by Northwest']
n1.iloc [::,[0,4,5]]
# Out:
#                       title                    character     n
# 840374   North by Northwest           Roger O. Thornhill   1.0
# 1404704  North by Northwest              Phillip Vandamm   3.0
# 343701   North by Northwest                The Professor   5.0
# 1634552  North by Northwest              Lester Townsend   7.0
# 1229083  North by Northwest                      Leonard   8.0
# 1746383  North by Northwest              Victor Larrabee  10.0
# 642085   North by Northwest                        Licht  11.0
# 447893   North by Northwest                    Dr. Cross  13.0
# 1454363  North by Northwest               Sergeant Flamm  14.0
# 198496   North by Northwest               Captain Junket  15.0
# 1334726  North by Northwest  Charley - Chicago Policeman  16.0

# %% [markdown]
# ### Display the entire cast, in "n"-order, of the 1972 film "Sleuth".

# %%
n_sorted = cast.sort_values ('n', ascending = True)
cast_sleuth = n_sorted [n_sorted ['title'] == 'Sleuth']
cast_sleuth_1972 = cast_sleuth [cast_sleuth['year'] == 1972]
cast_sleuth_1972.iloc [::, [0,1,4,5]]
# Out:
#           title    year                   character    n
# 1644328  Sleuth  1972.0                 Andrew Wyke  1.0
# 314691   Sleuth  1972.0                 Milo Tindle  2.0
# 360365   Sleuth  1972.0           Inspector Doppler  3.0
# 1412647  Sleuth  1972.0  Detective Sergeant Tarrant  4.0
# 1396572  Sleuth  1972.0      Police Constable Higgs  6.0

# %% [markdown]
# ### Now display the entire cast, in "n"-order, of the 2007 version of "Sleuth".

# %%
cast_sleuth_2007 = cast_sleuth [cast_sleuth['year'] == 2007]
cast_sleuth_2007.iloc [::, [0,1,4,5]]
# Out:
#           title    year          character    n
# 314692   Sleuth  2007.0             Andrew  1.0
# 1246855  Sleuth  2007.0               Milo  2.0
# 1741124  Sleuth  2007.0        Man on T.V.  3.0
# 250297   Sleuth  2007.0  Other Man on T.V.  NaN
# 360366   Sleuth  2007.0  Inspector Doppler  NaN

# %% [markdown]
# ### How many roles were credited in the silent 1921 version of Hamlet?

# %%
n_s_na = cast.sort_values('n',ascending  = True).dropna()
n_hamlet = n_s_na [n_s_na ['title'] == 'Hamlet']
n_h_1921 = n_hamlet [n_hamlet ['year'] == 1921]
print (n_h_1921.iloc [::, [0,1,4,5]])
print (n_h_1921 ['n'].count ())
# Out:
#           title    year     character    n
# 442224   Hamlet  1921.0  K?nig Hamlet  2.0
# 2106367  Hamlet  1921.0       Horatio  5.0
# 1095274  Hamlet  1921.0      Polonius  6.0
# 535307   Hamlet  1921.0       Laertes  7.0
# 7438     Hamlet  1921.0   Fortinbras,  9.0
# 5

# %% [markdown]
# ### How many roles were credited in Branagh’s 1996 Hamlet?

# %%
n_h_1996 = n_hamlet [n_hamlet ['year'] ==  1996]
print (n_h_1996.iloc [::, [0,1,4,5]])
print (n_h_1996 ['n'].count ())
# Out:
#           title    year                 character     n
# 1615     Hamlet  1996.0     Attendant to Claudius   1.0
# 92106    Hamlet  1996.0        English Ambassador   2.0
# 206181   Hamlet  1996.0     Attendant to Claudius   3.0
# 211111   Hamlet  1996.0  Ghost of Hamlet's Father   4.0
# 250281   Hamlet  1996.0                    Hamlet   5.0
# 262368   Hamlet  1996.0                  Polonius   6.0
# 283598   Hamlet  1996.0                    Priest   7.0
# 307699   Hamlet  1996.0     Attendant to Claudius   8.0
# 482982   Hamlet  1996.0         First Gravedigger  10.0
# 500005   Hamlet  1996.0             Stage Manager  11.0
# 555725   Hamlet  1996.0                  Reynaldo  13.0
# 577284   Hamlet  1996.0              Guildenstern  14.0
# 582748   Hamlet  1996.0                    Yorick  15.0
# 633587   Hamlet  1996.0                  Lucianus  17.0
# 679290   Hamlet  1996.0                   Horatio  18.0
# 683298   Hamlet  1996.0                 Francisco  19.0
# ...

# %% [markdown]
# ### How many "Hamlet" roles have been listed in all film credits through history?

# %%
print (n_hamlet['n'].count())
# Out:
# 168

# %% [markdown]
# ### How many people have played an "Ophelia"?

# %%
c_ophelia = cast [cast ['character'] == 'Ophelia']
print (c_ophelia ['name'].unique() )
print (c_ophelia ['name'].nunique() )
# Out:
# ['Amy Bourque' 'Josie Chisholm' 'Crystal Cordero' 'Lucas Grabeel'
#  'Catherine (IV) Lord' 'Justine Mooritz' 'Hannah Elizabeth Smith']
# 7

# %% [markdown]
# ### How many people have played a role called "The Dude"?

# %%
c_TD = cast [cast ['character'] == 'The Dude']
print (c_TD['name'].unique())
print (c_TD['name'].nunique())
# Out:
# ['Jeff Bridges' 'Jordan Cann' 'Scott Crowell' 'Chris DeMarcus'
#  'Mike Donlin' 'Devin The Dude' 'Matthew (XIX) James' 'Christopher Kadish'
#  'Jason Loughridge' 'Steve Lyons' 'Mark Alan Meek' 'Jerry Miley'
#  'House Peters Jr.' 'Thomas (VIII) Porter' 'Jason Priestley'
#  'Bobby Styles']
# 16

# %% [markdown]
# ### How many people have played a role called "The Stranger"?

# %%
c_ts = cast [cast ['character'] == 'The Stranger']
print (c_ts ['name'].unique ())
print (c_ts ['name'].nunique())
# Out:
# ['Hassan Mutlag Al-Maraiyeh' 'Vincent H. Alexander' 'Tony Anthony'
#  'Phil Arnold' 'Ryan Andrew Balas' 'Cristi Balea' 'Richard Baron'
#  'Nigel Barrett' 'Harry Basch' 'Arben Biba' 'Richard (XV) Bishop'
#  'Frank Borzage' 'Pinkas Braun' 'Gerard Butler' 'Nicholas Campbell'
#  'Nik Catello' 'Lyster Chambers' 'Michael V. Chastain' 'Chazz'
#  'Alan Christy' 'Jason (VII) Coleman' 'Hallam Cooley' 'Sharlto Copley'
#  'Ste Cork' 'Gino Corrado' 'Harp Corrigan' 'Walter Coy' 'Shawn Crosby'
#  'Jemo Dalipovic' 'Matt Danner' 'Helmut Dantine' 'Josh Davidson'
#  'William B. Davidson' 'Jim Davis' 'Ben (V) Dawson' 'Michael Dawu'
#  'Tim DeKay' 'Patrick Dempsey' 'Joe DeRita' 'Alex Diakun' 'Billy Drago'
#  'Tex Driscoll' 'Rainer D?sing' 'Eddie Eagle' 'Clint Eastwood'
#  'James L. Edwards' 'Sam Elliott' 'Alberto Esparza' 'Manuchehr Farid'
#  'Michael Ian Farrell' 'George Fawcett' 'Federico Fellini'
#  'James Stephen Finn' "Maurice 'Lefty' Flynn" 'Johnston Forbes-Robertson'
# ...

# %% [markdown]
# ### How many roles has Sidney Poitier played throughout his career?

# %%
c_sp = cast[cast ['name'] == 'Sidney Poitier']
print (c_sp['character'].unique())
print (c_sp ['character'].nunique())
# Out:
# ['Gordon Ralfe' 'Manny Durrell' 'Walter Lee Younger' 'Dr. Matt Younger'
#  'Sgt. Eddie Towler' 'Rau-Ru' 'Gregory W. Miller' 'John Kane' 'Buck'
#  'Reverend Msimangu' 'Toller' 'Tommy Tyler' 'Jack Parks' 'Inman Jackson'
#  'Gates Watson' 'John Prentice' 'Virgil Tibbs' 'Clyde Williams'
#  'Homer Smith' 'Roy Parmenter' 'Dr. Luther Brooks' 'Eddie Cook' 'Porgy'
#  'Doctor' 'Robertson' 'Night Club Extra' 'Warren Stantin' 'Donald Crease'
#  'Kimani Wa Karanja' 'Ben Munceford' 'Noah Cullen' 'Simon of Cyrene'
#  'FBI Deputy Director Carter Preston' 'Aly Mansuh' 'Jason Higgs' 'Obam'
#  'Alan Newell' 'Shack Twala' 'Mark Thackeray' 'Steve Jackson' 'Marcus']
# 41

# %% [markdown]
# ### How many roles has Judi Dench played?

# %%
c_jd = cast[cast ['name'] == 'Judi Dench']
print (c_jd['character'].unique())
print (c_jd ['character'].nunique())
# Out:
# []
# 0

# %% [markdown]
# ### List the supporting roles (having n=2) played by Cary Grant in the 1940s, in order by year.

# %%
y_sort = cast.sort_values ('year', ascending = True)
y_1940 = y_sort[y_sort ['year'].between (1940,1949)]
y_1940_2 = y_1940[y_1940['n'] == 2]
y3 = y_1940_2[y_1940_2['name'] == 'Cary Grant']
y3.iloc [::,[0,1,2,3,4,5]]
# Out:
#                    title    year        name   type    character    n
# 840371  My Favorite Wife  1940.0  Cary Grant  actor         Nick  2.0
# 840381    Penny Serenade  1941.0  Cary Grant  actor  Roger Adams  2.0

# %% [markdown]
# ### List the leading roles that Cary Grant played in the 1940s in order by year.

# %%
y_cg = y_1940[y_1940['name'] == 'Cary Grant']
y_cg1 = y_cg [y_cg ['n'] == 1]
print (y_cg1.iloc [::, [0,1,4]])
# Out:
#                                        title    year              character
# 840353                       His Girl Friday  1940.0           Walter Burns
# 840397               The Howards of Virginia  1940.0            Matt Howard
# 840399                The Philadelphia Story  1940.0     C. K. Dexter Haven
# 840386                             Suspicion  1941.0                Johnnie
# 840401                  The Talk of the Town  1942.0           Leopold Dilg
# 840377                 Once Upon a Honeymoon  1942.0  Patrick 'Pat' O'Toole
# 840344                     Destination Tokyo  1943.0          Capt. Cassidy
# 840370                             Mr. Lucky  1943.0        Joe Bascopolous
# 840369                             Mr. Lucky  1943.0              Joe Adams
# 840378                      Once Upon a Time  1944.0            Jerry Flynn
# 840336                  Arsenic and Old Lace  1944.0      Mortimer Brewster
# ...

# %% [markdown]
# ### How many roles were available for actors in the 1950s?

# %%
c_50s = cast [cast ['year'].between (1951,1959)]
print (c_50s['character'].count())
# Out:
# 122755

# %% [markdown]
# ### How many roles were available for actresses in the 1950s?

# %% [markdown]
# ### How many leading roles (n=1) were available from the beginning of film history through 1980?

# %%
y = cast.sort_values ('year', ascending = True)
y2 = y[y['year'].between (1894,1980)]
print (y2['character'].unique())
print (y2['character'].nunique())
# Out:
# ['Himself - the Director of the New York Central Railroad' 'Mr. Hamilton'
#  'Lion' ... 'Prof. Tsuchiya' 'Sardara' 'Tsong']
# 388767

# %% [markdown]
# ### How many non-leading roles were available through from the beginning of film history through 1980?

# %%
y2_n = y2[y2['n'] != 1]
print (y2_n['character'].unique())
print (y2_n['character'].nunique())
# Out:
# ['Himself - the Director of the New York Central Railroad' 'Mr. Hamilton'
#  'Lion' ... 'Prof. Tsuchiya' 'Sardara' 'Tsong']
# 364422

# %% [markdown]
# ### How many roles through 1980 were minor enough that they did not warrant a numeric "n" rank?

# %%
o = cast [(cast ['n'].isna()) & (cast ['year'] <= 1980)]
o['n'].shape[0]
# Out:
# 299849

# %%
cast.value_counts(dropna = False)
# Out:
# title                     year    name                     type   character           n
# Eskimo Limon              1978.0  Jonathan Sagall          actor  Momo                3.0     2
# August (III)              2011.0  George Barbakadze        actor  Background          82.0    2
# Gold                      2016.0  Jameson Macmillan        actor  Motel Guest         NaN     2
# Fucking My Way Back Home  2016.0  Julio Benitez Guardiola  actor  Alberto             3.0     2
# Angoor                    1982.0  Sanjeev Kumar            actor  Ashok               1.0     2
#                                                                                              ..
# NaN                       2015.0  Elijah Meyer             actor  Landen's Friend     NaN     1
#                                   Emma (V) Meyer           actor  Brock's Girlfriend  NaN     1
#                                   Gabriel (II) Michael     actor  Psychopath          NaN     1
# ...
